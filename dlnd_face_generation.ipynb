# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /opt/conda/lib/python3.6/site-packages
# Requirement already satisfied: olefile in /opt/conda/lib/python3.6/site-packages (from pillow)
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !echo "y" | pip uninstall matplotlib
# !pip install matplotlib==2.0.2
# Out:
# Uninstalling matplotlib-2.0.2:
#   /opt/conda/lib/python3.6/site-packages/__pycache__/pylab.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib-2.0.2-py3.6-nspkg.pth
#   /opt/conda/lib/python3.6/site-packages/matplotlib-2.0.2.dist-info/DESCRIPTION.rst
#   /opt/conda/lib/python3.6/site-packages/matplotlib-2.0.2.dist-info/INSTALLER
#   /opt/conda/lib/python3.6/site-packages/matplotlib-2.0.2.dist-info/METADATA
#   /opt/conda/lib/python3.6/site-packages/matplotlib-2.0.2.dist-info/RECORD
#   /opt/conda/lib/python3.6/site-packages/matplotlib-2.0.2.dist-info/WHEEL
#   /opt/conda/lib/python3.6/site-packages/matplotlib-2.0.2.dist-info/metadata.json
#   /opt/conda/lib/python3.6/site-packages/matplotlib-2.0.2.dist-info/namespace_packages.txt
#   /opt/conda/lib/python3.6/site-packages/matplotlib-2.0.2.dist-info/top_level.txt
#   /opt/conda/lib/python3.6/site-packages/matplotlib/.libs/libpng16-3e9b18e2.so.16.21.0
#   /opt/conda/lib/python3.6/site-packages/matplotlib/.libs/libz-a147dcb0.so.1.2.3
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/_cm.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/_cm_listed.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/_color_data.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/_mathtext_data.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/_pylab_helpers.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/_version.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/afm.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/animation.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/artist.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/axis.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/backend_bases.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/backend_managers.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/backend_tools.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/bezier.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/blocking_input.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/cbook.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/cm.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/collections.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/colorbar.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/colors.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/container.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/contour.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/dates.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/docstring.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/dviread.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/figure.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/finance.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/font_manager.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/fontconfig_pattern.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/gridspec.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/hatch.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/image.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/legend.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/legend_handler.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/lines.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/markers.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/mathtext.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/mlab.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/offsetbox.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/patches.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/path.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/patheffects.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/pylab.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/pyplot.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/quiver.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/rcsetup.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/sankey.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/scale.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/spines.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/stackplot.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/streamplot.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/table.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/texmanager.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/text.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/textpath.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/ticker.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/tight_bbox.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/tight_layout.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/transforms.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/type1font.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/units.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/__pycache__/widgets.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_cm.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_cm_listed.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_cntr.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_color_data.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_contour.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_delaunay.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_image.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_mathtext_data.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_path.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_png.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_qhull.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_tri.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/_version.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/afm.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/animation.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/artist.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/axes/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/axes/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/axes/__pycache__/_axes.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/axes/__pycache__/_base.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/axes/__pycache__/_subplots.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_base.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_subplots.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/axis.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backend_bases.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backend_managers.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backend_tools.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_agg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_cairo.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_gdk.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_gtk.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_gtk3.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_gtk3agg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_gtk3cairo.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_gtkagg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_gtkcairo.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_macosx.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_mixed.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_nbagg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_pdf.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_pgf.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_ps.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_qt4.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_qt4agg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_qt5.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_qt5agg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_svg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_template.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_tkagg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_webagg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_webagg_core.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_wx.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/backend_wxagg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/qt4_compat.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/qt_compat.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/tkagg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/windowing.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/__pycache__/wx_compat.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/_backend_agg.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/_tkagg.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_cairo.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_gdk.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_gtk.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_gtk3.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_gtk3agg.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_gtk3cairo.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_gtkagg.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_gtkcairo.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_macosx.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_mixed.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_nbagg.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_pdf.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_pgf.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_ps.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_qt4.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_qt4agg.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_qt5agg.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_svg.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_template.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_tkagg.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_webagg.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_webagg_core.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_wx.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/backend_wxagg.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/qt4_compat.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/qt_compat.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/qt_editor/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/qt_editor/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/qt_editor/__pycache__/figureoptions.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/qt_editor/__pycache__/formlayout.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/qt_editor/__pycache__/formsubplottool.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/qt_editor/figureoptions.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/qt_editor/formlayout.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/qt_editor/formsubplottool.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/tkagg.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/all_figures.html
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/css/boilerplate.css
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/css/fbm.css
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/css/page.css
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/ipython_inline_figure.html
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-bg_diagonals-thick_18_b81900_40x40.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-bg_diagonals-thick_20_666666_40x40.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-bg_flat_10_000000_40x100.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-bg_glass_100_f6f6f6_1x400.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-bg_glass_100_fdf5ce_1x400.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-bg_glass_65_ffffff_1x400.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-bg_gloss-wave_35_f6a828_500x100.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-bg_highlight-soft_100_eeeeee_1x100.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-bg_highlight-soft_75_ffe45c_1x100.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-icons_222222_256x240.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-icons_228ef1_256x240.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-icons_ef8c08_256x240.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-icons_ffd27a_256x240.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images/ui-icons_ffffff_256x240.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/jquery-ui.min.css
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/js/jquery-1.11.3.min.js
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/jquery/js/jquery-ui.min.js
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/mpl.js
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/mpl_tornado.js
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/nbagg_mpl.js
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/nbagg_uat.ipynb
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/web_backend/single_figure.html
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/windowing.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/backends/wx_compat.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/bezier.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/blocking_input.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/cbook.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/cm.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/collections.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/colorbar.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/colors.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/compat/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/compat/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/compat/__pycache__/subprocess.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/compat/subprocess.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/container.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/contour.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/dates.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/delaunay/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/delaunay/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/delaunay/__pycache__/interpolate.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/delaunay/__pycache__/testfuncs.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/delaunay/__pycache__/triangulate.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/delaunay/interpolate.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/delaunay/testfuncs.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/delaunay/triangulate.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/docstring.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/dviread.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/figure.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/finance.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/fontconfig_pattern.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/ft2font.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/gridspec.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/hatch.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/image.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/legend.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/legend_handler.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/lines.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/markers.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mathtext.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mlab.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/cmex10.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/cmmi10.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/cmr10.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/cmsy10.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/cmtt10.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pagd8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pagdo8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pagk8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pagko8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pbkd8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pbkdi8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pbkl8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pbkli8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pcrb8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pcrbo8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pcrr8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pcrro8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/phvb8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/phvb8an.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/phvbo8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/phvbo8an.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/phvl8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/phvlo8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/phvr8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/phvr8an.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/phvro8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/phvro8an.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pncb8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pncbi8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pncr8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pncri8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pplb8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pplbi8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pplr8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pplri8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/psyr.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/ptmb8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/ptmbi8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/ptmr8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/ptmri8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/putb8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/putbi8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/putr8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/putri8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pzcmi8a.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/afm/pzdr.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Courier-Bold.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Courier-BoldOblique.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Courier-Oblique.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Courier.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Helvetica-Bold.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Helvetica-BoldOblique.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Helvetica-Oblique.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Helvetica.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Symbol.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Times-Bold.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Times-BoldItalic.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Times-Italic.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/Times-Roman.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/ZapfDingbats.afm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts/readme.txt
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/LICENSE_STIX
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/back.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/back.pdf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/back.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/back.svg
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/back_large.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/back_large.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/filesave.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/filesave.pdf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/filesave.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/filesave.svg
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/filesave_large.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/filesave_large.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/forward.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/forward.pdf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/forward.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/forward.svg
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/forward_large.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/forward_large.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/hand.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/hand.pdf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/hand.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/hand.svg
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/hand_large.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/home.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/home.pdf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/home.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/home.svg
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/home_large.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/home_large.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/matplotlib.pdf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/matplotlib.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/matplotlib.ppm
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/matplotlib.svg
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/matplotlib_large.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/move.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/move.pdf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/move.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/move.svg
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/move_large.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/move_large.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/qt4_editor_options.pdf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/qt4_editor_options.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/qt4_editor_options.svg
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/qt4_editor_options_large.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/subplots.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/subplots.pdf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/subplots.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/subplots.svg
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/subplots_large.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/subplots_large.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/zoom_to_rect.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/zoom_to_rect.pdf
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/zoom_to_rect.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/zoom_to_rect.svg
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/zoom_to_rect_large.gif
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/images/zoom_to_rect_large.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/AAPL.dat.gz
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/INTC.dat.gz
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/Minduka_Present_Blue_Pack.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/None_vs_nearest-pdf.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/README.txt
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/aapl.csv
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/aapl.npy.gz
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/ada.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/axes_grid/bivariate_normal.npy
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/ct.raw.gz
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/data_x_x2_x3.csv
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/demodata.csv
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/eeg.dat
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/embedding_in_wx3.xrc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/goog.npy
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/grace_hopper.jpg
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/grace_hopper.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/jacksboro_fault_dem.npz
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/logo2.png
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/membrane.dat
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/msft.csv
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/percent_bachelors_degrees_women_usa.csv
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/sample_data/s1045.ima.gz
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/bmh.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/dark_background.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/fivethirtyeight.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/ggplot.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/grayscale.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-bright.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-colorblind.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-dark-palette.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-dark.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-darkgrid.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-deep.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-muted.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-notebook.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-paper.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-pastel.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-poster.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-talk.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-ticks.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-white.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn-whitegrid.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/seaborn.mplstyle
#   /opt/conda/lib/python3.6/site-packages/matplotlib/offsetbox.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/patches.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/path.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/patheffects.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/projections/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/projections/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/projections/__pycache__/geo.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/projections/__pycache__/polar.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/projections/geo.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/projections/polar.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/pylab.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/quiver.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/rcsetup.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sankey.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/scale.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/__pycache__/mathmpl.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/__pycache__/only_directives.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/__pycache__/plot_directive.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/mathmpl.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/only_directives.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/plot_directive.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/tests/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/tests/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/tests/__pycache__/test_tinypages.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/tests/test_tinypages.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/tests/tinypages/__pycache__/conf.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/tests/tinypages/_static/README.txt
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/tests/tinypages/conf.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/tests/tinypages/index.rst
#   /opt/conda/lib/python3.6/site-packages/matplotlib/sphinxext/tests/tinypages/some_plots.rst
#   /opt/conda/lib/python3.6/site-packages/matplotlib/spines.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/stackplot.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/streamplot.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/style/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/style/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/style/__pycache__/core.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/style/core.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/table.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/__pycache__/compare.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/__pycache__/decorators.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/__pycache__/disable_internet.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/__pycache__/exceptions.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/__pycache__/noseclasses.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/compare.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/decorators.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/disable_internet.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/exceptions.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/Duration.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/Epoch.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/EpochConverter.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/StrConverter.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/UnitDbl.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/UnitDblConverter.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/UnitDblFormatter.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/__pycache__/Duration.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/__pycache__/Epoch.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/__pycache__/EpochConverter.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/__pycache__/StrConverter.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/__pycache__/UnitDbl.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/__pycache__/UnitDblConverter.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/__pycache__/UnitDblFormatter.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/jpl_units/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/testing/noseclasses.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__init__.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_afm.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_agg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_animation.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_arrow_patches.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_artist.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_axes.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_backend_bases.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_backend_pdf.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_backend_pgf.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_backend_ps.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_backend_qt4.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_backend_qt5.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_backend_svg.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_basic.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_bbox_tight.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_cbook.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_coding_standards.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_collections.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_colorbar.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_colors.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_compare_images.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_container.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_contour.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_cycles.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_dates.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_delaunay.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_dviread.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_figure.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tests/__pycache__/test_font_manager.cpython-36.pyc
# ...
#   /opt/conda/lib/python3.6/site-packages/matplotlib/tri/tritools.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/ttconv.cpython-36m-x86_64-linux-gnu.so
#   /opt/conda/lib/python3.6/site-packages/matplotlib/type1font.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/units.py
#   /opt/conda/lib/python3.6/site-packages/matplotlib/widgets.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/__pycache__/exceltools.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/__pycache__/gtktools.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__init__.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/anchored_artists.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/angle_helper.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/axes_divider.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/axes_grid.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/axes_rgb.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/axes_size.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/axis_artist.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/axisline_style.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/axislines.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/clip_path.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/colorbar.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/floating_axes.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/grid_finder.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/grid_helper_curvelinear.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/inset_locator.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/__pycache__/parasite_axes.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/anchored_artists.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/angle_helper.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/axes_divider.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/axes_grid.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/axes_rgb.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/axes_size.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/axis_artist.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/axisline_style.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/axislines.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/clip_path.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/colorbar.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/floating_axes.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/grid_finder.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/grid_helper_curvelinear.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/inset_locator.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid/parasite_axes.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/__init__.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/__pycache__/anchored_artists.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/__pycache__/axes_divider.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/__pycache__/axes_grid.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/__pycache__/axes_rgb.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/__pycache__/axes_size.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/__pycache__/colorbar.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/__pycache__/inset_locator.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/__pycache__/mpl_axes.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/__pycache__/parasite_axes.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/anchored_artists.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/axes_divider.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/axes_grid.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/axes_rgb.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/axes_size.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/colorbar.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/inset_locator.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/mpl_axes.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axes_grid1/parasite_axes.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/__init__.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/__pycache__/angle_helper.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/__pycache__/axis_artist.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/__pycache__/axisline_style.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/__pycache__/axislines.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/__pycache__/clip_path.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/__pycache__/floating_axes.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/__pycache__/grid_finder.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/__pycache__/grid_helper_curvelinear.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/angle_helper.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/axis_artist.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/axisline_style.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/axislines.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/clip_path.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/floating_axes.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/grid_finder.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/axisartist/grid_helper_curvelinear.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/exceltools.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/gtktools.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/__init__.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/__pycache__/art3d.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/__pycache__/axes3d.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/__pycache__/axis3d.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/__pycache__/proj3d.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/art3d.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axis3d.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/proj3d.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/__init__.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/__pycache__/__init__.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/__pycache__/test_axes_grid.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/__pycache__/test_axes_grid1.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/__pycache__/test_mplot3d.cpython-36.pyc
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_axes_grid/imagegrid_cbar_mode.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_axes_grid1/divider_append_axes.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_axes_grid1/divider_append_axes.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_axes_grid1/divider_append_axes.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_axes_grid1/inset_locator.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_axes_grid1/twin_axes_empty_and_removed.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/axes3d_cla.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/axes3d_labelpad.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/bar3d.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/bar3d.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/bar3d.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/contour3d.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/contour3d.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/contour3d.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/contourf3d.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/contourf3d.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/contourf3d.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/contourf3d_fill.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/contourf3d_fill.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/contourf3d_fill.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/lines3d.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/lines3d.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/lines3d.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/mixedsubplot.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/mixedsubplot.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/mixedsubplot.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/quiver3d.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/quiver3d.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/quiver3d.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/quiver3d_empty.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/quiver3d_empty.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/quiver3d_empty.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/quiver3d_masked.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/quiver3d_masked.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/quiver3d_masked.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/quiver3d_pivot_middle.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/quiver3d_pivot_tail.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/scatter3d.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/scatter3d.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/scatter3d.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/scatter3d_color.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/surface3d.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/surface3d.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/surface3d.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/text3d.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/text3d.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/text3d.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/trisurf3d.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/trisurf3d.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/trisurf3d.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/wireframe3d.pdf
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/wireframe3d.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/wireframe3d.svg
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/wireframe3dzerocstride.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/baseline_images/test_mplot3d/wireframe3dzerorstride.png
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/test_axes_grid.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/test_axes_grid1.py
#   /opt/conda/lib/python3.6/site-packages/mpl_toolkits/tests/test_mplot3d.py
#   /opt/conda/lib/python3.6/site-packages/pylab.py
# Proceed (y/n)?   Successfully uninstalled matplotlib-2.0.2
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting matplotlib==2.0.2
#   Using cached matplotlib-2.0.2-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: pyparsing!=2.0.0,!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /opt/conda/lib/python3.6/site-packages (from matplotlib==2.0.2)
# Requirement already satisfied: numpy>=1.7.1 in /opt/conda/lib/python3.6/site-packages (from matplotlib==2.0.2)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.6/site-packages (from matplotlib==2.0.2)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.6/site-packages (from matplotlib==2.0.2)
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.6/site-packages (from matplotlib==2.0.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.6/site-packages/cycler-0.10.0-py3.6.egg (from matplotlib==2.0.2)
# Installing collected packages: matplotlib
# Successfully installed matplotlib-2.0.2
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""

import os

from matplotlib import pyplot

from glob import glob
# %matplotlib inline

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.3.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    
    input_images = tf.placeholder(tf.float32, shape=(None, image_width, image_height, image_channels), name='input_img')
    z_data = tf.placeholder(tf.float32, shape=(None, z_dim), name='z_data')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')

    return input_images, z_data, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_2/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/opt/conda/lib/python3.6/runpy.py", line 193, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/opt/conda/lib/python3.6/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>\n    app.launch_new_instance()', 'File "/opt/conda/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance\n    app.start()', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start\n    self.io_loop.start()', 'File "/opt/conda/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start\n    super(ZMQIOLoop, self).start()', 'File "/opt/conda/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start\n    handler_func(fd_obj, events)', 'File "/opt/conda/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "/opt/conda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/opt/conda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request\n    user_expressions, allow_stdin)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2856, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-6-87bd33ae7d1f>", line 24, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/home/workspace/face_generation/problem_unittests.py", line 12, in func_wrapper\n    result = func(*args)', 'File "/home/workspace/face_generation/problem_unittests.py", line 68, in test_model_inputs\n    _check_input(learn_rate, [], \'Learning Rate\')', 'File "/home/workspace/face_generation/problem_unittests.py", line 34, in _check_input\n    _assert_tensor_shape(tensor, shape, \'Real Input\')', 'File "/home/workspace/face_generation/problem_unittests.py", line 20, in _assert_tensor_shape\n    assert tf.assert_rank(tensor, len(shape), message=\'{} has wrong rank\'.format(display_name))', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py", line 175, in wrapped\n    return _add_should_use_warning(fn(*args, **kwargs))', 'File "/opt/conda/lib/python3.6/site-packag ...
# ==================================
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    alpha = 0.2
    #print(images.get_shape())
    with tf.variable_scope('discriminator', reuse=reuse):
        
        h1 = tf.layers.conv2d(images, 32, 5, strides=1, padding='same',
                             kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d())
        relu1 = tf.nn.relu(alpha * h1)
        #print(relu1.get_shape())
        # shape 28, 28, 32
        
        h2 = tf.layers.conv2d(relu1, 64, 5, strides=2, padding='same',
                             kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d())
        norm2 = tf.layers.batch_normalization(h2, training=True)
        relu2 = tf.nn.relu(alpha * norm2)
        #print(relu2.get_shape())
        # shape 14, 14, 64
        
        h3 = tf.layers.conv2d(relu2, 128, 5, strides=2, padding='same',
                             kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d())
        norm3 = tf.layers.batch_normalization(h3, training=True)
        relu3 = tf.nn.relu(alpha * norm3)
        #print(relu3.get_shape())
        # shape 7, 7, 128
        
        
        flat = tf.reshape(relu2, (-1, 7 * 7 *128))
        logits = tf.layers.dense(flat, 1, activation=None,
                                kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d())
        #print(logits.get_shape())
        out = tf.sigmoid(logits)
        #print(out.get_shape())

    return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function

    alpha = 0.2
    with tf.variable_scope('generator', reuse=not(is_train)):
        # define the 1-st layer
        h1 = tf.layers.dense(z, 7 * 7 * 128, activation=None,
                            kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d())
        
        conv1 = tf.reshape(h1, (-1, 7, 7, 128))
        norm1 = tf.layers.batch_normalization(conv1, training=is_train)
        relu1 = tf.nn.relu(alpha * norm1)
        #print(relu1.get_shape())
        # shape 7, 7, 128
        
        conv2 = tf.layers.conv2d_transpose(relu1, 64, 5, strides=2, padding='same',
                                          kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d())
        norm2 = tf.layers.batch_normalization(conv2, training=is_train)
        relu2 = tf.nn.relu(alpha * norm2)
        #print(relu2.get_shape())
        # shape 14, 14, 64
        
        conv3 = tf.layers.conv2d_transpose(relu2, 32, 5, strides=2, padding='same',
                                          kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d())
        norm3 = tf.layers.batch_normalization(conv3, training=is_train)
        relu3 = tf.nn.relu(alpha * norm3)
        #print(relu3.get_shape())
        # shape 28, 28, 32

        logits = tf.layers.conv2d_transpose(relu3, out_channel_dim, 5, strides=1, padding='same',
                                           kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d())
        out = tf.tanh(logits)
        
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    
    smooth = 0.1
    g_model = generator(input_z, out_channel_dim, is_train=True)
    
    d_model_real, d_logits_real = discriminator(input_real, reuse=False)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    
    d_loss_real = tf.reduce_mean(
                  tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                          labels=tf.ones_like(d_model_real) * (1 - smooth)))
    
    d_loss_fake = tf.reduce_mean(
                  tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                          labels=tf.zeros_like(d_model_fake)))
    
    d_loss = d_loss_real + d_loss_fake

    g_loss = tf.reduce_mean(
                 tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                         labels=tf.ones_like(d_model_fake)))
    
    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    
    # Optimizers

    # Get the trainable_variables, split into G and D parts
    t_vars = tf.trainable_variables()
    
    g_vars = [var for var in t_vars if var.name.startswith('generator')]
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]

    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)        
    
    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    
    input_images_pl, z_data_pl, learning_rate_var = model_inputs(data_shape[1], data_shape[2], data_shape[3], z_dim)

    d_loss, g_loss = model_loss(input_images_pl, z_data_pl, data_shape[3])

    d_train_opt, g_train_opt = model_opt(d_loss, g_loss, learning_rate_var, beta1)
    
    with tf.Session() as sess:
        
        sess.run(tf.global_variables_initializer())
        

        for epoch_i in range(epoch_count):
            batch_num = 0
            for batch_images in get_batches(batch_size):
                if batch_images.shape[0] < batch_size:
                    break
                
                batch_images = batch_images * 2.0

                batch_z = np.random.uniform(-1.0, 1.0, size=(batch_size, z_dim))
                feed = {input_images_pl: batch_images, z_data_pl: batch_z, 
                        learning_rate_var: learning_rate}


                _ = sess.run(d_train_opt, feed)
                _ = sess.run(g_train_opt, feed)



                # eval every 100 batches
                if batch_num % 200 == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = d_loss.eval({input_images_pl: batch_images, z_data_pl: batch_z})
                    train_loss_g = g_loss.eval({z_data_pl: batch_z})
                    
                    #_ = sess.run(gen_out_pl, feed_dict={z_data_pl: sample_test})
                    
                    show_generator_output(sess, 16, z_data_pl, data_shape[3], data_image_mode)

                    print("Epoch {}/{}-{} batch ...".format(epoch_i + 1, epoch_count, batch_num * batch_size),
                      "Discriminator Loss: {:.4f}...".format(train_loss_d),
                      "Generator Loss: {:.4f}".format(train_loss_g))    
                    # Save losses to view after training
                    #losses.append((train_loss_d, train_loss_g))

                batch_num += 1

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64
z_dim = 110
learning_rate = 0.0006
beta1 = 0.35
tf.reset_default_graph()

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2-0 batch ... Discriminator Loss: 1.3379... Generator Loss: 0.6432
# Epoch 1/2-12800 batch ... Discriminator Loss: 1.3609... Generator Loss: 0.5946
# Epoch 1/2-25600 batch ... Discriminator Loss: 1.5275... Generator Loss: 0.5292
# Epoch 1/2-38400 batch ... Discriminator Loss: 1.3404... Generator Loss: 0.6590
# Epoch 1/2-51200 batch ... Discriminator Loss: 1.3136... Generator Loss: 0.8989
# Epoch 2/2-0 batch ... Discriminator Loss: 1.3157... Generator Loss: 0.8370
# Epoch 2/2-12800 batch ... Discriminator Loss: 1.3281... Generator Loss: 0.8263
# Epoch 2/2-25600 batch ... Discriminator Loss: 1.3130... Generator Loss: 0.8873
# Epoch 2/2-38400 batch ... Discriminator Loss: 1.2967... Generator Loss: 0.8835
# Epoch 2/2-51200 batch ... Discriminator Loss: 1.2955... Generator Loss: 0.9220

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 32
z_dim = 128
learning_rate = 0.00063
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1-0 batch ... Discriminator Loss: 1.3665... Generator Loss: 0.6085
# Epoch 1/1-6400 batch ... Discriminator Loss: 1.4014... Generator Loss: 0.7378
# Epoch 1/1-12800 batch ... Discriminator Loss: 1.4249... Generator Loss: 0.7610
# Epoch 1/1-19200 batch ... Discriminator Loss: 1.3530... Generator Loss: 0.8141
# Epoch 1/1-25600 batch ... Discriminator Loss: 1.3819... Generator Loss: 0.7768
# Epoch 1/1-32000 batch ... Discriminator Loss: 1.3699... Generator Loss: 0.7809
# Epoch 1/1-38400 batch ... Discriminator Loss: 1.3379... Generator Loss: 0.8792
# Epoch 1/1-44800 batch ... Discriminator Loss: 1.4338... Generator Loss: 0.6866
# Epoch 1/1-51200 batch ... Discriminator Loss: 1.3469... Generator Loss: 0.7895
# Epoch 1/1-57600 batch ... Discriminator Loss: 1.3595... Generator Loss: 0.8323
# Epoch 1/1-64000 batch ... Discriminator Loss: 1.3821... Generator Loss: 0.7933
# Epoch 1/1-70400 batch ... Discriminator Loss: 1.4247... Generator Loss: 0.7636
# Epoch 1/1-76800 batch ... Discriminator Loss: 1.3387... Generator Loss: 0.8060
# Epoch 1/1-83200 batch ... Discriminator Loss: 1.3713... Generator Loss: 0.7817
# Epoch 1/1-89600 batch ... Discriminator Loss: 1.3791... Generator Loss: 0.7721
# Epoch 1/1-96000 batch ... Discriminator Loss: 1.4006... Generator Loss: 0.7725
# Epoch 1/1-102400 batch ... Discriminator Loss: 1.3646... Generator Loss: 0.8036
# Epoch 1/1-108800 batch ... Discriminator Loss: 1.3757... Generator Loss: 0.7856
# Epoch 1/1-115200 batch ... Discriminator Loss: 1.4106... Generator Loss: 0.7785
# Epoch 1/1-121600 batch ... Discriminator Loss: 1.4055... Generator Loss: 0.7853
# Epoch 1/1-128000 batch ... Discriminator Loss: 1.3838... Generator Loss: 0.7675
# Epoch 1/1-134400 batch ... Discriminator Loss: 1.4240... Generator Loss: 0.7599
# Epoch 1/1-140800 batch ... Discriminator Loss: 1.3843... Generator Loss: 0.7307
# Epoch 1/1-147200 batch ... Discriminator Loss: 1.4065... Generator Loss: 0.7238
# Epoch 1/1-153600 batch ... Discriminator Loss: 1.3648... Generator Loss: 0.7932
# Epoch 1/1-160000 batch ... Discriminator Loss: 1.3878... Generator Loss: 0.8274
# Epoch 1/1-166400 batch ... Discriminator Loss: 1.4110... Generator Loss: 0.7475
# Epoch 1/1-172800 batch ... Discriminator Loss: 1.4199... Generator Loss: 0.7347
# Epoch 1/1-179200 batch ... Discriminator Loss: 1.3715... Generator Loss: 0.7545
# Epoch 1/1-185600 batch ... Discriminator Loss: 1.3764... Generator Loss: 0.7797
# Epoch 1/1-192000 batch ... Discriminator Loss: 1.3703... Generator Loss: 0.6880
# Epoch 1/1-198400 batch ... Discriminator Loss: 1.4070... Generator Loss: 0.8100

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
